# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

sns.set_theme()

# %matplotlib inline

# %%
# Complexity of Air-Traffic Flow

import matplotlib.pyplot as plt
import tikzplotlib
import json
with open('log/test_models/test_D2MAV_cn_0.json') as file:
    full_data = json.load(file)
print(np.mean([full_data[i]['los'] for i in range (0, len(full_data))]))
print(len(full_data))
conjestion_data = full_data[0]['congestion_distribution']
# Extract keys and counts
del conjestion_data['0']
del conjestion_data['80']
keys = list(conjestion_data.keys())
counts = list(conjestion_data.values())

# Calculate probabilities
total_count = sum(counts)
probabilities = [count / total_count for count in counts]

# Calculate entropy
entropy = -sum(p * np.log2(p) for p in probabilities if p > 0)

# Print entropy
print(f"Entropy of the distribution: {entropy:.4f}")

# Create a bar plot
# Calculate the total number of aircraft
total_count = sum(counts)

# Convert counts to percentages
percentages = [(count / total_count) for count in counts]
bar_color = (197 / 255, 87 / 255, 0 / 255)
# Create a bar plot using percentages
plt.bar(keys, percentages, color=bar_color)
plt.grid(True, color='black')

# Set the border (spines) color to black
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')

# Set the tick labels to black
plt.xticks(color='black')
plt.yticks(color='black')

plt.ylim(0, 1.05)

# Add labels and title
plt.xlabel('Altitude Levels')
plt.ylabel('Percentage of Aircraft')
plt.title('Aircraft Congestion at Different Altitudes')

# Save the plot with a transparent background and tight bounding box
plt.savefig('congestion_plot.png', transparent=True, bbox_inches='tight')

# Display the plot
tikzplotlib.save("cn-plot-0.tex")
plt.show()
# Out:
# 6.526315789473684
# 114
# Entropy of the distribution: 2.1770

# %%
# Complexity of Air-Traffic Flow

import matplotlib.pyplot as plt
import json
with open('log/test_models/test_D2MAV_cn_005.json') as file:
    full_data = json.load(file)
print(np.mean([full_data[i]['los'] for i in range (0, len(full_data))]))
conjestion_data = full_data[0]['congestion_distribution']
# Extract keys and counts
del conjestion_data['0']
del conjestion_data['80']
keys = list(conjestion_data.keys())
counts = list(conjestion_data.values())

# Calculate probabilities
total_count = sum(counts)
probabilities = [count / total_count for count in counts]

# Calculate entropy
entropy = -sum(p * np.log2(p) for p in probabilities if p > 0)

# Print entropy
print(f"Entropy of the distribution: {entropy:.4f}")

# Create a bar plot
# Calculate the total number of aircraft
total_count = sum(counts)

# Convert counts to percentages
percentages = [(count / total_count) for count in counts]
bar_color = (197 / 255, 87 / 255, 0 / 255)
# Create a bar plot using percentages
plt.bar(keys, percentages, color=bar_color)
plt.grid(True, color='black')

# Set the border (spines) color to black
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')

# Set the tick labels to black
plt.xticks(color='black')
plt.yticks(color='black')

plt.ylim(0, 1.05)

# Add labels and title
plt.xlabel('Altitude Levels')
plt.ylabel('Percentage of Aircraft')
plt.title('Aircraft Congestion at Different Altitudes')

# Save the plot with a transparent background and tight bounding box
plt.savefig('congestion_plot.png', transparent=True, bbox_inches='tight')

# Display the plot
plt.show()
# Out:
# 6.4035087719298245
# Entropy of the distribution: 2.1957

# %%
# Complexity of Air-Traffic Flow

import matplotlib.pyplot as plt
import json
with open('log/test_models/test_D2MAV_cn_01.json') as file:
    full_data = json.load(file)
print(np.mean([full_data[i]['los'] for i in range (0, len(full_data))]))
conjestion_data = full_data[0]['congestion_distribution']
# Extract keys and counts
del conjestion_data['0']
del conjestion_data['80']
keys = list(conjestion_data.keys())
counts = list(conjestion_data.values())

# Calculate probabilities
total_count = sum(counts)
probabilities = [count / total_count for count in counts]

# Calculate entropy
entropy = -sum(p * np.log2(p) for p in probabilities if p > 0)

# Print entropy
print(f"Entropy of the distribution: {entropy:.4f}")

# Create a bar plot
# Calculate the total number of aircraft
total_count = sum(counts)

# Convert counts to percentages
percentages = [(count / total_count) for count in counts]
bar_color = (197 / 255, 87 / 255, 0 / 255)
# Create a bar plot using percentages
plt.bar(keys, percentages, color=bar_color)
plt.grid(True, color='black')

# Set the border (spines) color to black
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')

# Set the tick labels to black
plt.xticks(color='black')
plt.yticks(color='black')

plt.ylim(0, 1.05)

# Add labels and title
plt.xlabel('Altitude Levels')
plt.ylabel('Percentage of Aircraft')
plt.title('Aircraft Congestion at Different Altitudes')

# Save the plot with a transparent background and tight bounding box
plt.savefig('congestion_plot.png', transparent=True, bbox_inches='tight')
tikzplotlib.save("cn-plot-01.tex")
# Display the plot
plt.show()
# Out:
# 6.368421052631579
# Entropy of the distribution: 2.2928

# %%
# Complexity of Air-Traffic Flow

import matplotlib.pyplot as plt
import json
with open('log/test_models/test_D2MAV_cn_02.json') as file:
    full_data = json.load(file)
print(np.mean([full_data[i]['los'] for i in range (0, len(full_data))]))
conjestion_data = full_data[0]['congestion_distribution']
# Extract keys and counts
del conjestion_data['0']
del conjestion_data['80']
keys = list(conjestion_data.keys())
counts = list(conjestion_data.values())

# Calculate probabilities
total_count = sum(counts)
probabilities = [count / total_count for count in counts]

# Calculate entropy
entropy = -sum(p * np.log2(p) for p in probabilities if p > 0)

# Print entropy
print(f"Entropy of the distribution: {entropy:.4f}")

# Create a bar plot
# Calculate the total number of aircraft
total_count = sum(counts)

# Convert counts to percentages
percentages = [(count / total_count) for count in counts]
bar_color = (197 / 255, 87 / 255, 0 / 255)
# Create a bar plot using percentages
plt.bar(keys, percentages, color=bar_color)
plt.grid(True, color='black')

# Set the border (spines) color to black
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')

# Set the tick labels to black
plt.xticks(color='black')
plt.yticks(color='black')

plt.ylim(0, 1.05)

# Add labels and title
plt.xlabel('Altitude Levels')
plt.ylabel('Percentage of Aircraft')
plt.title('Aircraft Congestion at Different Altitudes')

# Save the plot with a transparent background and tight bounding box
plt.savefig('congestion_plot.png', transparent=True, bbox_inches='tight')
tikzplotlib.save("cn-plot-02.tex")
# Display the plot
plt.show()
# Out:
# 12.350877192982455
# Entropy of the distribution: 2.0642

# %%
# Complexity of Air-Traffic Flow

import matplotlib.pyplot as plt
import json
with open('log/test_models/test_D2MAV_cn_03.json') as file:
    full_data = json.load(file)
print(np.mean([full_data[i]['los'] for i in range (0, len(full_data))]))
conjestion_data = full_data[0]['congestion_distribution']
# Extract keys and counts
del conjestion_data['0']
del conjestion_data['80']
keys = list(conjestion_data.keys())
counts = list(conjestion_data.values())

# Calculate probabilities
total_count = sum(counts)
probabilities = [count / total_count for count in counts]

# Calculate entropy
entropy = -sum(p * np.log2(p) for p in probabilities if p > 0)

# Print entropy
print(f"Entropy of the distribution: {entropy:.4f}")

# Create a bar plot
# Calculate the total number of aircraft
total_count = sum(counts)

# Convert counts to percentages
percentages = [(count / total_count) for count in counts]
bar_color = (197 / 255, 87 / 255, 0 / 255)
# Create a bar plot using percentages
plt.bar(keys, percentages, color=bar_color)
plt.grid(True, color='black')

# Set the border (spines) color to black
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')

# Set the tick labels to black
plt.xticks(color='black')
plt.yticks(color='black')

plt.ylim(0, 1.05)

# Add labels and title
plt.xlabel('Altitude Levels')
plt.ylabel('Percentage of Aircraft')
plt.title('Aircraft Congestion at Different Altitudes')

# Save the plot with a transparent background and tight bounding box
plt.savefig('congestion_plot.png', transparent=True, bbox_inches='tight')
tikzplotlib.save("cn-plot-03.tex")
# Display the plot
plt.show()
# Out:
# 13.578947368421053
# Entropy of the distribution: 1.6546

# %%
import matplotlib.pyplot as plt
import json
with open('log/test_models/test_D2MAV_cn_04.json') as file:
    full_data = json.load(file)
conjestion_data = full_data[0]['congestion_distribution']
print(np.mean([full_data[i]['los'] for i in range (0, len(full_data))]))
# Extract keys and counts
del conjestion_data['0']
del conjestion_data['80']
keys = list(conjestion_data.keys())
counts = list(conjestion_data.values())

# Calculate probabilities
total_count = sum(counts)
probabilities = [count / total_count for count in counts]

# Calculate entropy
entropy = -sum(p * np.log2(p) for p in probabilities if p > 0)

# Print entropy
print(f"Entropy of the distribution: {entropy:.4f}")

# Create a bar plot
# Calculate the total number of aircraft
total_count = sum(counts)

# Convert counts to percentages
percentages = [(count / total_count) for count in counts]

# Create a bar plot using percentages
bar_color = (197 / 255, 87 / 255, 0 / 255)
plt.bar(keys, percentages, color=bar_color)
plt.grid(True, color='black')

# Set the border (spines) color to black
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')

# Set the tick labels to black
plt.xticks(color='black')
plt.yticks(color='black')
plt.ylim(0, 1.05)
# Add labels and title
plt.xlabel('Altitude Levels')
plt.ylabel('Percentage of Aircraft')
plt.title('Aircraft Congestion at Different Altitudes')

# Save the plot with a transparent background and tight bounding box
plt.savefig('congestion_noise_plot.png', transparent=True, bbox_inches='tight')
tikzplotlib.save("cn-plot-04.tex")

# Display the plot
plt.show()
# Out:
# 13.473684210526315
# Entropy of the distribution: 1.7780

# %%
import matplotlib.pyplot as plt
import json
with open('log/test_models/test_D2MAV_cn_05.json') as file:
    full_data = json.load(file)
conjestion_data = full_data[0]['congestion_distribution']
print(np.mean([full_data[i]['los'] for i in range (0, len(full_data))]))
# Extract keys and counts
del conjestion_data['0']
del conjestion_data['80']
keys = list(conjestion_data.keys())
counts = list(conjestion_data.values())

# Calculate probabilities
total_count = sum(counts)
probabilities = [count / total_count for count in counts]

# Calculate entropy
entropy = -sum(p * np.log2(p) for p in probabilities if p > 0)

# Print entropy
print(f"Entropy of the distribution: {entropy:.4f}")

# Create a bar plot
# Calculate the total number of aircraft
total_count = sum(counts)

# Convert counts to percentages
percentages = [(count / total_count) for count in counts]

# Create a bar plot using percentages
bar_color = (197 / 255, 87 / 255, 0 / 255)
plt.bar(keys, percentages, color=bar_color)
plt.grid(True, color='black')

# Set the border (spines) color to black
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')

# Set the tick labels to black
plt.xticks(color='black')
plt.yticks(color='black')
plt.ylim(0, 1.05)
# Add labels and title
plt.xlabel('Altitude Levels')
plt.ylabel('Percentage of Aircraft')
plt.title('Aircraft Congestion at Different Altitudes')

# Save the plot with a transparent background and tight bounding box
plt.savefig('congestion_noise_plot.png', transparent=True, bbox_inches='tight')
tikzplotlib.save("cn-plot-05.tex")
# Display the plot
plt.show()
# Out:
# 15.24561403508772
# Entropy of the distribution: 1.6584

# %%
import matplotlib.pyplot as plt
import json
with open('log/test_models/test_D2MAV_cn_06.json') as file:
    full_data = json.load(file)
conjestion_data = full_data[0]['congestion_distribution']
print(np.mean([full_data[i]['los'] for i in range (0, len(full_data))]))
# Extract keys and counts
del conjestion_data['0']
del conjestion_data['80']
keys = list(conjestion_data.keys())
counts = list(conjestion_data.values())

# Calculate probabilities
total_count = sum(counts)
probabilities = [count / total_count for count in counts]

# Calculate entropy
entropy = -sum(p * np.log2(p) for p in probabilities if p > 0)

# Print entropy
print(f"Entropy of the distribution: {entropy:.4f}")

# Create a bar plot
# Calculate the total number of aircraft
total_count = sum(counts)

# Convert counts to percentages
percentages = [(count / total_count) for count in counts]

# Create a bar plot using percentages
bar_color = (197 / 255, 87 / 255, 0 / 255)
plt.bar(keys, percentages, color=bar_color)
plt.grid(True, color='black')

# Set the border (spines) color to black
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')

# Set the tick labels to black
plt.xticks(color='black')
plt.yticks(color='black')
plt.ylim(0, 1.05)
# Add labels and title
plt.xlabel('Altitude Levels')
plt.ylabel('Percentage of Aircraft')
plt.title('Aircraft Congestion at Different Altitudes')

# Save the plot with a transparent background and tight bounding box
plt.savefig('congestion_noise_plot.png', transparent=True, bbox_inches='tight')
tikzplotlib.save("cn-plot-06.tex")
# Display the plot
plt.show()
# Out:
# 17.105263157894736
# Entropy of the distribution: 1.3073

# %%
import matplotlib.pyplot as plt
import json
with open('log/test_models/test_D2MAV_cn_1.json') as file:
    full_data = json.load(file)
conjestion_data = full_data[0]['congestion_distribution']
print(np.mean([full_data[i]['los'] for i in range (0, len(full_data))]))
print(len([full_data[i]['los'] for i in range (0, len(full_data))]))
# Extract keys and counts
del conjestion_data['0']
del conjestion_data['80']
keys = list(conjestion_data.keys())
counts = list(conjestion_data.values())

# Calculate probabilities
total_count = sum(counts)
probabilities = [count / total_count for count in counts]

# Calculate entropy
entropy = -sum(p * np.log2(p) for p in probabilities if p > 0)

# Print entropy
print(f"Entropy of the distribution: {entropy:.4f}")

# Calculate the total number of aircraft
total_count = sum(counts)

# Convert counts to percentages
percentages = [(count / total_count) for count in counts]

# Create a bar plot using percentages
plt.bar(keys, percentages, color=bar_color)
plt.grid(True, color='black')

# Set the border (spines) color to black
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')

# Set the tick labels to black
plt.xticks(color='black')
plt.yticks(color='black')
plt.ylim(0, 1.05)
# Add labels and title
plt.xlabel('Altitude Levels')
plt.ylabel('Percentage of Aircraft')
plt.title('Aircraft Congestion at Different Altitudes')

# Save the plot with a transparent background and tight bounding box
plt.savefig('noise_plot.png', transparent=True, bbox_inches='tight')
tikzplotlib.save("cn-plot-1.tex")
# Display the plot
plt.show()
# Out:
# 16.0
# 28
# Entropy of the distribution: 1.0038

# %%
import matplotlib.pyplot as plt
import json
with open('log/test_models/test_D2MAV_red_spacing_0.json') as file:
    full_data = json.load(file)
conjestion_data = full_data[0]['congestion_distribution']
print(np.mean([full_data[i]['los'] for i in range (0, len(full_data))]))
print(len([full_data[i]['los'] for i in range (0, len(full_data))]))
# Extract keys and counts
del conjestion_data['0']
del conjestion_data['80']
keys = list(conjestion_data.keys())
counts = list(conjestion_data.values())

# Calculate probabilities
total_count = sum(counts)
probabilities = [count / total_count for count in counts]

# Calculate entropy
entropy = -sum(p * np.log2(p) for p in probabilities if p > 0)

# Print entropy
print(f"Entropy of the distribution: {entropy:.4f}")

# Calculate the total number of aircraft
total_count = sum(counts)

# Convert counts to percentages
percentages = [(count / total_count) for count in counts]

# Create a bar plot using percentages
plt.bar(keys, percentages, color=bar_color)
plt.grid(True, color='black')

# Set the border (spines) color to black
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')

# Set the tick labels to black
plt.xticks(color='black')
plt.yticks(color='black')
plt.ylim(0, 1.05)
# Add labels and title
plt.xlabel('Altitude Levels')
plt.ylabel('Percentage of Aircraft')
plt.title('Aircraft Congestion at Different Altitudes')

# Save the plot with a transparent background and tight bounding box
# plt.savefig('noise_plot.png', transparent=True, bbox_inches='tight')
# tikzplotlib.save("cn-plot-1.tex")
# Display the plot
plt.show()
# Out:
# 8.84971098265896
# 173
# Entropy of the distribution: 2.2342

# %%
import matplotlib.pyplot as plt
import json
with open('log/test_models/test_D2MAV_red_spacing_05.json') as file:
    full_data = json.load(file)
conjestion_data = full_data[0]['congestion_distribution']
print(np.mean([full_data[i]['los'] for i in range (0, len(full_data))]))
print(len([full_data[i]['los'] for i in range (0, len(full_data))]))
# Extract keys and counts
del conjestion_data['0']
del conjestion_data['80']
keys = list(conjestion_data.keys())
counts = list(conjestion_data.values())

# Calculate probabilities
total_count = sum(counts)
probabilities = [count / total_count for count in counts]

# Calculate entropy
entropy = -sum(p * np.log2(p) for p in probabilities if p > 0)

# Print entropy
print(f"Entropy of the distribution: {entropy:.4f}")

# Calculate the total number of aircraft
total_count = sum(counts)

# Convert counts to percentages
percentages = [(count / total_count) for count in counts]

# Create a bar plot using percentages
plt.bar(keys, percentages, color=bar_color)
plt.grid(True, color='black')

# Set the border (spines) color to black
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')

# Set the tick labels to black
plt.xticks(color='black')
plt.yticks(color='black')
plt.ylim(0, 1.05)
# Add labels and title
plt.xlabel('Altitude Levels')
plt.ylabel('Percentage of Aircraft')
plt.title('Aircraft Congestion at Different Altitudes')

# Save the plot with a transparent background and tight bounding box
# plt.savefig('noise_plot.png', transparent=True, bbox_inches='tight')
# tikzplotlib.save("cn-plot-1.tex")
# Display the plot
plt.show()
# Out:
# 18.75722543352601
# 173
# Entropy of the distribution: 1.4430

# %%
import matplotlib.pyplot as plt
import json
with open('log/test_models/test_D2MAV_cn_1_new_scenario.json') as file:
    full_data = json.load(file)
conjestion_data = full_data[0]['congestion_distribution']
print(np.mean([full_data[i]['los'] for i in range (0, len(full_data))]))
print(len([full_data[i]['los'] for i in range (0, len(full_data))]))
# Extract keys and counts
del conjestion_data['0']
del conjestion_data['80']
keys = list(conjestion_data.keys())
counts = list(conjestion_data.values())

# Calculate probabilities
total_count = sum(counts)
probabilities = [count / total_count for count in counts]

# Calculate entropy
entropy = -sum(p * np.log2(p) for p in probabilities if p > 0)

# Print entropy
print(f"Entropy of the distribution: {entropy:.4f}")

# Calculate the total number of aircraft
total_count = sum(counts)

# Convert counts to percentages
percentages = [(count / total_count) for count in counts]

# Create a bar plot using percentages
plt.bar(keys, percentages, color=bar_color)
plt.grid(True, color='black')

# Set the border (spines) color to black
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')

# Set the tick labels to black
plt.xticks(color='black')
plt.yticks(color='black')
plt.ylim(0, 1.05)
# Add labels and title
plt.xlabel('Altitude Levels')
plt.ylabel('Percentage of Aircraft')
plt.title('Aircraft Congestion at Different Altitudes')

# Save the plot with a transparent background and tight bounding box
# plt.savefig('noise_plot.png', transparent=True, bbox_inches='tight')
# tikzplotlib.save("cn-plot-1.tex")
# Display the plot
plt.show()
# Out:
# 66.0
# 43
# Entropy of the distribution: 1.0038

# %%
import matplotlib.pyplot as plt
import tikzplotlib
import numpy as np

dict_of_data_points = {'0':0, '01': 0.1, '02': 0.2, '03': 0.3, '04': 0.4, '05': 0.5, '06': 0.6, '07': 0.7, '08': 0.8, '09': 0.9, '1': 1}
dict_of_data_points = {'0':0, '01': 0.1, '02': 0.2, '03': 0.3, '04': 0.4, '05': 0.5, '06': 0.6, '07': 0.7, '08': 0.8, '09': 0.9, '1': 1}
avg_los_dict = {}
std_dev_lost_dict = {}
noise_dict = {}
for key in dict_of_data_points.keys():
    with open(f'log/test_models/test_D2MAV_cn_{key}.json') as file:
        full_data = json.load(file)

    print("Checking Values: ", key, len(full_data))
    los_list = [full_data[i]['los'] for i in range (0, len(full_data))]
    avg_los_dict[dict_of_data_points[key]] = np.mean(los_list)
    std_dev_lost_dict[dict_of_data_points[key]] = np.std(los_list)
    noise_set = [entry['avg_noise'] for entry in full_data]
    noise_all_datapoints = [item for i in range(0, len(noise_set)) for item in noise_set[i].values()]
    noise_dict[dict_of_data_points[key]] = np.median(noise_all_datapoints)

tradeoff_param = sorted(avg_los_dict.keys())
avg_los_vals = [avg_los_dict[param] for param in tradeoff_param]
std_los_vals = [std_dev_lost_dict[param] for param in tradeoff_param]
noise_vals = [noise_dict[param] for param in tradeoff_param]
print("LOS Dict: ", avg_los_dict)
# plt.figure(figsize=(8, 6))
plt.errorbar(noise_vals, avg_los_vals, yerr=std_los_vals, fmt='-o', label='Avg LOS with Std Dev', ecolor='blue', elinewidth=2, capsize=5, capthick=2)

for i, param in enumerate(tradeoff_param):
    plt.text(noise_vals[i] + 0.1, avg_los_vals[i], f'{param}', fontsize=9, ha='left', va='center')

plt.xlabel('Median Noise Increase')
plt.ylabel('Average LOS Occurences')
plt.grid(True)
tikzplotlib.save("tradeoff_plot_2.tex")
plt.show()
# Out:
# Checking Values:  0 114
# Checking Values:  01 114
# Checking Values:  02 114
# Checking Values:  03 114
# Checking Values:  04 114
# Checking Values:  05 114
# Checking Values:  06 114
# Checking Values:  07 114
# Checking Values:  08 114
# Checking Values:  09 114
# Checking Values:  1 28
# LOS Dict:  {0: 6.526315789473684, 0.1: 6.368421052631579, 0.2: 12.350877192982455, 0.3: 13.578947368421053, 0.4: 13.473684210526315, 0.5: 15.24561403508772, 0.6: 17.105263157894736, 0.7: 16.0, 0.8: 16.0, 0.9: 16.0, 1: 16.0}

# %%
import matplotlib.pyplot as plt
import tikzplotlib
import numpy as np

dict_of_data_points = {'0':0, '01': 0.1, '02': 0.2, '03': 0.3, '04': 0.4, '05': 0.5, '06': 0.6, '07': 0.7, '08': 0.8, '09': 0.9, '1': 1}
dict_of_data_points = {'0':0, '01': 0.1, '02': 0.2, '03': 0.3, '04': 0.4, '05': 0.5, '06': 0.6, '07': 0.7, '08': 0.8, '09': 0.9, '1': 1}
avg_los_dict = {}
std_dev_lost_dict = {}
noise_dict = {}
congestion_distribution = {}
for key in dict_of_data_points.keys():
    with open(f'log/test_models/test_D2MAV_cn_{key}.json') as file:
        full_data = json.load(file)
    print("Checking Values: ", key, len(full_data))
    total_count_3000 = sum([full_data[i]['congestion_distribution']['3000'] for i in range(0, len(full_data))])
    total_count_all = sum([sum([full_data[i]['congestion_distribution'][key_2] for key_2 in full_data[i]['congestion_distribution']]) for i in range(0, len(full_data))]) 
    congestion_distribution[dict_of_data_points[key]] = total_count_3000 / total_count_all
    # congestion_distribution[dict_of_data_points[key]] = [full_data[i]['congestion_distribution']['3000'] / sum([full_data[i]['congestion_distribution'][key_2] for key_2 in full_data[i]['congestion_distribution']]) for i in range(0, len(full_data))]
    # print("Len: ", len(congestion_distribution))
    los_list = [full_data[i]['los'] for i in range (0, len(full_data))]
    avg_los_dict[dict_of_data_points[key]] = np.mean(los_list)
    std_dev_lost_dict[dict_of_data_points[key]] = np.std(los_list)
    noise_set = [entry['avg_noise'] for entry in full_data]
    noise_all_datapoints = [item for i in range(0, len(noise_set)) for item in noise_set[i].values()]
    noise_dict[dict_of_data_points[key]] = np.median(noise_all_datapoints)
    # print("Len 2: ", len(noise_dict))

tradeoff_param = sorted(avg_los_dict.keys())
avg_los_vals = [avg_los_dict[param] for param in tradeoff_param]
std_los_vals = [std_dev_lost_dict[param] for param in tradeoff_param]
noise_vals = [noise_dict[param] for param in tradeoff_param]
congestion_vals = [congestion_distribution[param] for param in tradeoff_param]
print(congestion_vals)
# plt.figure(figsize=(8, 6))
print(noise_vals, congestion_vals)
plt.errorbar(noise_vals, congestion_vals, fmt='-o', label='Avg LOS with Std Dev', ecolor='blue', elinewidth=2, capsize=5, capthick=2)
# plt.scatter(noise_vals, congestion_vals)
for i, param in enumerate(tradeoff_param):
    plt.text(noise_vals[i] + 0.1, congestion_vals[i], f'{param}', fontsize=9, ha='left', va='center')

plt.xlabel('Median Noise Increase')
plt.ylabel('Percentage of Aircraft at Maximum Altitude')
plt.grid(True)
tikzplotlib.save("tradeoff_plot_1.tex")
plt.show()
# Out:
# Checking Values:  0 114
# Checking Values:  01 114
# Checking Values:  02 114
# Checking Values:  03 114
# Checking Values:  04 114
# Checking Values:  05 114
# Checking Values:  06 114
# Checking Values:  07 114
# Checking Values:  08 114
# Checking Values:  09 114
# Checking Values:  1 28
# [0.19940250145924315, 0.20697964622732018, 0.43201656951454087, 0.5690893901420218, 0.5362241448095031, 0.5429099569869539, 0.7463147480837758, 0.8195847504949489, 0.8195847504949489, 0.8195838598984898, 0.8195811244950795]
# [23.787495427943256, 22.309710890616234, 21.988914071745754, 21.465381706449485, 21.37506741999011, 20.95960241200963, 20.489503257027742, 20.32388856536385, 20.32388856536385, 20.32388856536385, 20.32388856536385] [0.19940250145924315, 0.20697964622732018, 0.43201656951454087, 0.5690893901420218, 0.5362241448095031, 0.5429099569869539, 0.7463147480837758, 0.8195847504949489, 0.8195847504949489, 0.8195838598984898, 0.8195811244950795]

# %%
with open('log/test_models/test_D2MAV_cn_0.json') as file:
    data_c = json.load(file)
with open('log/test_models/test_D2MAV_noise_congestion.json') as file:
    data_cn = json.load(file)
avg_noise_inc_safe = [entry['avg_noise'] for entry in data_c]
avg_noise_inc_01 = [entry['avg_noise'] for entry in data_cn]
noise_histogram_01 = [item for i in range(0, len(avg_noise_inc_01)) for item in avg_noise_inc_01[i].values()]

# %%
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tikzplotlib
import numpy as np

dict_of_data_points = {'0': 0, '01': 0.1, '02': 0.2, '03': 0.3, '04': 0.4, '05': 0.5, '06': 0.6, '07': 0.7, '08': 0.8, '09': 0.9, '1': 1}
palette = {
    '0.0': (255 / 255, 255 / 255, 255 / 255),
    '0.1': (156 / 255, 200 / 255, 0 / 255),
    '0.2': (0 / 255, 156 / 255, 156 / 255),
    '0.3': (111 / 255, 123 / 255, 132 / 255),
    '0.4': (132 / 255, 123 / 255, 111 / 255),
    '0.5': (111 / 255, 123 / 255, 0 / 255),
    '0.6': (191 / 255, 87 / 255, 0 / 255),
    '0.7': (200 / 255, 150 / 255, 100 / 255),
    '0.8': (150 / 255, 200 / 255, 150 / 255),
    '0.9': (100 / 255, 100 / 255, 200 / 255),
    '1.0': (50 / 255, 50 / 255, 200 / 255)
}

# List to hold all the data for each category
all_data = []

# Iterate over the dictionary keys
for key in dict_of_data_points.keys():
    with open(f'log/test_models/test_D2MAV_cn_{key}.json') as file:
        full_data = json.load(file)
    
    # Extract the 'avg_noise' values
    avg_noise_inc = [entry['avg_noise'] for entry in full_data]
    noise_histogram = [item for i in range(len(avg_noise_inc)) for item in avg_noise_inc[i].values()]

    # Append the data for the current key to the all_data list
    for value in noise_histogram:
        all_data.append({'Category': dict_of_data_points[key], 'Value': value})

# Create a DataFrame from the accumulated data
data = pd.DataFrame(all_data)

# Set the context for larger fonts
sns.set_context("talk", font_scale=1.2)

# Create the figure
plt.figure(figsize=(12, 8))

# Create a box plot with all categories side-by-side
sns.boxplot(x='Category', y='Value', data=data, whis=np.inf, linewidth=2, palette=palette, width=0.6)

# Add title and labels
plt.xlabel('Tradeoff Parameter Value')
plt.ylabel('Noise Increase (dB)')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
plt.yticks(color='black')

# Save and show the plot
plt.savefig('noise_box_plot_combined.png', transparent=True, bbox_inches='tight')
tikzplotlib.save("noise_box_plot.tex")
plt.show()
# Out:
# /tmp/ipykernel_6956/3552366129.py:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Category', y='Value', data=data, whis=np.inf, linewidth=2, palette=palette, width=0.6)

# %%
with open('log/test_models/test_D2MAV_cn_0.json') as file:
    data_c = json.load(file)
with open('log/test_models/test_D2MAV_cn_05.json') as file:
    data_cn = json.load(file)
with open('log/test_models/test_D2MAV_cn_025.json') as file:
    data_cn_25 = json.load(file)
with open('log/test_models/test_D2MAV_cn_075.json') as file:
    data_cn_75 = json.load(file)
with open('log/test_models/test_D2MAV_cn_005.json') as file:
    data_cn_005 = json.load(file)
with open('log/test_models/test_D2MAV_cn_06.json') as file:
    data_cn_06 = json.load(file)
with open('log/test_models/test_D2MAV_cn_1.json') as file:
    data_n = json.load(file)
avg_noise_inc_safe = [entry['avg_noise'] for entry in data_c]
avg_noise_inc_01 = [entry['avg_noise'] for entry in data_cn]
avg_noise_inc_005 = [entry['avg_noise'] for entry in data_cn_005]
avg_noise_inc_25 = [entry['avg_noise'] for entry in data_cn_25]
avg_noise_inc_06 = [entry['avg_noise'] for entry in data_cn_06]
avg_noise_inc_75 = [entry['avg_noise'] for entry in data_cn_75]
avg_noise_inc_n = [entry['avg_noise'] for entry in data_n]
# print(avg_noise_inc_safe)

noise_histogram_01 = [item for i in range(0, len(avg_noise_inc_01)) for item in avg_noise_inc_01[i].values()]
noise_hist_005 = [item for i in range(0, len(avg_noise_inc_005)) for item in avg_noise_inc_005[i].values()]
noise_hist_safe = [item for i in range(0, len(avg_noise_inc_safe)) for item in avg_noise_inc_safe[i].values()]
noise_hist_25 = [item for i in range(0, len(avg_noise_inc_25)) for item in avg_noise_inc_25[i].values()]
noise_hist_06 = [item for i in range(0, len(avg_noise_inc_06)) for item in avg_noise_inc_06[i].values()]
noise_hist_75 = [item for i in range(0, len(avg_noise_inc_75)) for item in avg_noise_inc_75[i].values()]
noise_hist_n = [item for i in range(0, len(avg_noise_inc_n)) for item in avg_noise_inc_n[i].values()]


data = pd.DataFrame({
    'Category': ['0']*len(noise_hist_safe) + ['0.05']*len(noise_hist_005) + ['0.25']*len(noise_hist_25) +['0.5']*len(noise_histogram_01) + ['0.6']*len(noise_hist_06) + ['0.75']*len(noise_hist_75) + ['1']*len(noise_hist_n),
    'Value': noise_hist_safe + noise_hist_005 + noise_hist_25 +noise_histogram_01 + noise_hist_06 + noise_hist_75 + noise_hist_n
})
# data = pd.DataFrame({
#     'Category': ['0']*len(noise_hist_safe) + ['1']*len(noise_hist_n),
#     'Value': noise_hist_safe + noise_hist_n
# })
# color_palette = [
#     (197 / 255, 87 / 255, 0 / 255),  # Orange
#     (0 / 255, 0 / 255, 255 / 255),   # Blue
#     (51 / 255, 63 / 255, 72 / 255)    # RGB(51, 63, 72)
# ]
palette = {
    '0': (255 / 255, 255 / 255, 255 / 255),
    '0.05': (156 / 255, 200 / 255, 0 / 255),
    '0.25': (0 / 255, 156 / 255, 156 / 255),
    '0.5': (111 / 255, 123 / 255, 132 / 255),
    '0.6': (132 / 255, 123 / 255, 111 / 255),
    '0.75': (111 / 255, 123 / 255, 0 / 255),
    '1': (191 / 255, 87 / 255, 0 / 255)
}
# Initialize the matplotlib figure
sns.set_context("talk", font_scale=1.2)  # You can adjust the font_scale value for larger/smaller text

# Create the figure
plt.figure(figsize=(10, 6))

# Create a box plot with narrower boxes
sns.boxplot(x='Category', y='Value', data=data, whis=np.inf, linewidth=2, palette=palette, width=0.6)

# Overlay a swarm plot
# for i, category in enumerate(data['Category'].unique()):
#     category_data = data_2[data_2['Category'] == category]
#     x_vals = np.full(len(category_data), i)  # x positions for the strip plot
#     plt.scatter(x_vals - 0.5, category_data['Value'], color=palette[category], alpha=0.6, s=5)  # adjust -0.2 to position points to the side


# Add title and labels
# plt.title('Cumulative Noise Increase over Different Models')
plt.xlabel('Model')
plt.ylabel('Noise Increase (dB)')
# plt.grid(True, color='black')
# Set the border (spines) color to black
# plt.gca().spines['top'].set_color('black')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
# plt.gca().spines['right'].set_color('black')

# Set the tick labels to black
# plt.xticks(color='black')
plt.yticks(color='black')
plt.savefig('noise_box_plot.png', transparent=True, bbox_inches='tight')
# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_6956/3119391247.py:62: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Category', y='Value', data=data, whis=np.inf, linewidth=2, palette=palette, width=0.6)

# %%
with open('log/test_models/test_D2MAV_red_spacing_0.json') as file:
    data_c = json.load(file)
with open('log/test_models/test_D2MAV_cn_05.json') as file:
    data_cn = json.load(file)
with open('log/test_models/test_D2MAV_cn_025.json') as file:
    data_cn_25 = json.load(file)
with open('log/test_models/test_D2MAV_cn_075.json') as file:
    data_cn_75 = json.load(file)
with open('log/test_models/test_D2MAV_cn_005.json') as file:
    data_cn_005 = json.load(file)
with open('log/test_models/test_D2MAV_cn_06.json') as file:
    data_cn_06 = json.load(file)
with open('log/test_models/test_D2MAV_red_spacing_05.json') as file:
    data_cn = json.load(file)
with open('log/test_models/test_D2MAV_cn_1_new_scenario.json') as file:
    data_n = json.load(file)
avg_noise_inc_safe = [entry['avg_noise'] for entry in data_c]
avg_noise_inc_01 = [entry['avg_noise'] for entry in data_cn]
avg_noise_inc_005 = [entry['avg_noise'] for entry in data_cn_005]
avg_noise_inc_25 = [entry['avg_noise'] for entry in data_cn_25]
avg_noise_inc_06 = [entry['avg_noise'] for entry in data_cn_06]
avg_noise_inc_cn = [entry['avg_noise'] for entry in data_cn]
avg_noise_inc_n = [entry['avg_noise'] for entry in data_n]
# print(avg_noise_inc_safe)

noise_histogram_01 = [item for i in range(0, len(avg_noise_inc_01)) for item in avg_noise_inc_01[i].values()]
noise_hist_005 = [item for i in range(0, len(avg_noise_inc_005)) for item in avg_noise_inc_005[i].values()]
noise_hist_safe = [item for i in range(0, len(avg_noise_inc_safe)) for item in avg_noise_inc_safe[i].values()]
noise_hist_25 = [item for i in range(0, len(avg_noise_inc_25)) for item in avg_noise_inc_25[i].values()]
noise_hist_06 = [item for i in range(0, len(avg_noise_inc_06)) for item in avg_noise_inc_06[i].values()]
noise_hist_75 = [item for i in range(0, len(avg_noise_inc_75)) for item in avg_noise_inc_75[i].values()]
noise_hist_n = [item for i in range(0, len(avg_noise_inc_n)) for item in avg_noise_inc_n[i].values()]
noise_hist_cn = [item for i in range(0, len(avg_noise_inc_cn)) for item in avg_noise_inc_cn[i].values()]


data = pd.DataFrame({
    'Category': ['0']*len(noise_hist_safe) + ['0.5']*len(noise_hist_cn) + ['1']*len(noise_hist_n),
    'Value': noise_hist_safe + noise_hist_cn + noise_hist_n
})
# data = pd.DataFrame({
#     'Category': ['0']*len(noise_hist_safe) + ['1']*len(noise_hist_n),
#     'Value': noise_hist_safe + noise_hist_n
# })
# color_palette = [
#     (197 / 255, 87 / 255, 0 / 255),  # Orange
#     (0 / 255, 0 / 255, 255 / 255),   # Blue
#     (51 / 255, 63 / 255, 72 / 255)    # RGB(51, 63, 72)
# ]
palette = {
    '0': (255 / 255, 255 / 255, 255 / 255),
    # '0.05': (156 / 255, 200 / 255, 0 / 255),
    # '0.25': (0 / 255, 156 / 255, 156 / 255),
    '0.5': (111 / 255, 123 / 255, 132 / 255),
    # '0.6': (132 / 255, 123 / 255, 111 / 255),
    # '0.75': (111 / 255, 123 / 255, 0 / 255),
    '1': (191 / 255, 87 / 255, 0 / 255)
}
# Initialize the matplotlib figure
sns.set_context("talk", font_scale=1.2)  # You can adjust the font_scale value for larger/smaller text

# Create the figure
plt.figure(figsize=(10, 6))

# Create a box plot with narrower boxes
sns.boxplot(x='Category', y='Value', data=data, whis=np.inf, linewidth=2, palette=palette, width=0.6)

# Overlay a swarm plot
# for i, category in enumerate(data['Category'].unique()):
#     category_data = data_2[data_2['Category'] == category]
#     x_vals = np.full(len(category_data), i)  # x positions for the strip plot
#     plt.scatter(x_vals - 0.5, category_data['Value'], color=palette[category], alpha=0.6, s=5)  # adjust -0.2 to position points to the side


# Add title and labels
# plt.title('Cumulative Noise Increase over Different Models')
plt.xlabel('Noise Weighting Factor')
plt.ylabel('Noise Increase (dB)')
# plt.grid(True, color='black')
# Set the border (spines) color to black
# plt.gca().spines['top'].set_color('black')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
# plt.gca().spines['right'].set_color('black')

# Set the tick labels to black
# plt.xticks(color='black')
plt.yticks(color='black')
plt.savefig('noise_box_plot.png', transparent=True, bbox_inches='tight')
# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_6956/3555492748.py:65: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Category', y='Value', data=data, whis=np.inf, linewidth=2, palette=palette, width=0.6)

# %%
# Metric = "nmacs" (number of loss of separation events) or "nmac_time" which is time in LOS
## Confusingly enough, this is LOS distance, not NMAC, even though it is named NMAC...

#metric = "nmacs"

metric = "nmac_time"


reward_no_tm = np.load("results/no_tm_9_25_2023_1/reward.npy")
nmac_no_tm = np.load(f"results/no_tm_9_25_2023_1/{metric}.npy")
iterations_no_tm = np.load("results/no_tm_9_25_2023_1/iteration_record.npy")

reward_no_tm_2 = np.load("results/no_tm_9_25_2023_2/reward.npy")
nmac_no_tm_2 = np.load(f"results/no_tm_9_25_2023_2/{metric}.npy")
iterations_no_tm_2 = np.load("results/no_tm_9_25_2023_2/iteration_record.npy")

nmac_no_tm = np.concatenate((nmac_no_tm, nmac_no_tm_2))

reward_uneq = np.load("results/unequip_9_25_2023/reward.npy")
nmac_uneq = np.load(f"results/unequip_9_25_2023/{metric}.npy")
iterations_uneq = np.load("results/unequip_9_25_2023/iteration_record.npy")


reward_tm_4 = np.load("results/tm_4_9_25_2023/reward.npy")
nmac_tm_4 = np.load(f"results/tm_4_9_25_2023/{metric}.npy")
iterations_tm_4 = np.load("results/tm_4_9_25_2023/iteration_record.npy")

reward_tm_4_2 = np.load("results/tm_4_9_25_2023_2/reward.npy")
nmac_tm_4_2 = np.load(f"results/tm_4_9_25_2023_2/{metric}.npy")
iterations_tm_4_2 = np.load("results/tm_4_9_25_2023_2/iteration_record.npy")


nmac_tm_4 = np.concatenate((nmac_tm_4, nmac_tm_4_2))


reward_tm_25 = np.load("results/tm_25_9_25_2023/reward.npy")
nmac_tm_25 = np.load(f"results/tm_25_9_25_2023/{metric}.npy")
iterations_tm_25 = np.load("results/tm_25_9_25_2023/iteration_record.npy")

reward_tm_25_2 = np.load("results/tm_25_9_25_2023_2/reward.npy")
nmac_tm_25_2 = np.load(f"results/tm_25_9_25_2023_2/{metric}.npy")
iterations_tm_25_2 = np.load("results/tm_25_9_25_2023_2/iteration_record.npy")


nmac_tm_25 = np.concatenate((nmac_tm_25, nmac_tm_25_2))


reward_tm_50 = np.load("results/tm_50_9_25_2023/reward.npy")
nmac_tm_50 = np.load(f"results/tm_50_9_25_2023/{metric}.npy")
iterations_tm_50 = np.load("results/tm_50_9_25_2023/iteration_record.npy")

reward_tm_50_2 = np.load("results/tm_50_9_25_2023_2/reward.npy")
nmac_tm_50_2 = np.load(f"results/tm_50_9_25_2023_2/{metric}.npy")
iterations_tm_50_2 = np.load("results/tm_50_9_25_2023_2/iteration_record.npy")


nmac_tm_50 = np.concatenate((nmac_tm_50, nmac_tm_50_2))


reward_tm_100 = np.load("results/tm_100_9_25_2023/reward.npy")
nmac_tm_100 = np.load(f"results/tm_100_9_25_2023/{metric}.npy")
iterations_tm_100 = np.load("results/tm_100_9_25_2023/iteration_record.npy")

reward_tm_100_2 = np.load("results/tm_100_9_25_2023_2/reward.npy")
nmac_tm_100_2 = np.load(f"results/tm_100_9_25_2023_2/{metric}.npy")
iterations_tm_100_2 = np.load("results/tm_100_9_25_2023_2/iteration_record.npy")


nmac_tm_100 = np.concatenate((nmac_tm_100, nmac_tm_100_2))


reward_tm_3 = np.load("results/tm_3_9_25_2023/reward.npy")
nmac_tm_3 = np.load(f"results/tm_3_9_25_2023/{metric}.npy")
iterations_tm_3 = np.load("results/tm_3_9_25_2023/iteration_record.npy")

reward_tm_3_2 = np.load("results/tm_3_9_25_2023_2/reward.npy")
nmac_tm_3_2 = np.load(f"results/tm_3_9_25_2023_2/{metric}.npy")
iterations_tm_3_2 = np.load("results/tm_3_9_25_2023_2/iteration_record.npy")


nmac_tm_3 = np.concatenate((nmac_tm_3, nmac_tm_3_2))


reward_tm_50_fix = np.load("results/tm_25_1500_9_25_2023/reward.npy") # this is actually capacity 50, not 25
nmac_tm_50_fix = np.load(f"results/tm_25_1500_9_25_2023/{metric}.npy")
iterations_tm_50_fix = np.load("results/tm_25_1500_9_25_2023/iteration_record.npy")

reward_tm_50_fix_2 = np.load("results/tm_25_1500_9_25_2023_2/reward.npy") # this is actually capacity 50 , not 25
nmac_tm_50_fix_2 = np.load(f"results/tm_25_1500_9_25_2023_2/{metric}.npy")
iterations_tm_50_fix_2 = np.load("results/tm_25_1500_9_25_2023_2/iteration_record.npy")

nmac_tm_50_fix = np.concatenate((nmac_tm_50_fix, nmac_tm_50_fix_2))


reward_tm_50_update = np.load("results/tm_50_1500_11_14_2023/reward.npy") 
nmac_tm_50_update = np.load(f"results/tm_50_1500_11_14_2023/{metric}.npy")
iterations_tm_50_update = np.load("results/tm_50_1500_11_14_2023/iteration_record.npy")



reward_tm_10_update = np.load("results/tm_10_1500_11_14_2023/reward.npy")
nmac_tm_10_update = np.load(f"results/tm_10_1500_11_14_2023/{metric}.npy")
iterations_tm_10_update = np.load("results/tm_10_1500_11_14_2023/iteration_record.npy")



fig = plt.figure(figsize=(12,8))

sns.set(font_scale = 1.5)

nmac_no_tm = pd.DataFrame(nmac_no_tm)
nmac_tm_4 = pd.DataFrame(nmac_tm_4)
nmac_tm_25 = pd.DataFrame(nmac_tm_25)
nmac_tm_50 = pd.DataFrame(nmac_tm_50)
nmac_tm_100 = pd.DataFrame(nmac_tm_100)
nmac_tm_3 = pd.DataFrame(nmac_tm_3)


nmac_tm_50_fix = pd.DataFrame(nmac_tm_50_fix)
nmac_tm_50_update = pd.DataFrame(nmac_tm_50_update)
nmac_tm_10_update = pd.DataFrame(nmac_tm_10_update)


nmac_uneq = pd.DataFrame(nmac_uneq)

RM = 50


plt.plot(nmac_no_tm.rolling(RM).mean())
plt.plot(nmac_uneq.rolling(RM).mean())

plt.plot(nmac_tm_4.rolling(RM).mean())
plt.plot(nmac_tm_25.rolling(RM).mean())
plt.plot(nmac_tm_100.rolling(RM).mean())
plt.plot(nmac_tm_3.rolling(RM).mean())
plt.plot(nmac_tm_50.rolling(RM).mean())



plt.plot(nmac_tm_50_fix.rolling(RM).mean())
plt.plot(nmac_tm_50_update.rolling(RM).mean())
plt.plot(nmac_tm_10_update.rolling(RM).mean())

plt.xlabel('Training Iteration')
plt.ylabel('Time in LOS (s)')
#plt.xlim(0,12500)
#plt.ylim(0,1000)
plt.legend(["Func-3a",
            "Unequipped", 
            "TM-4" ,
            "TM-25", 
            "TM-100", 
            "TM-3", 
            "TM-50",
            "TM-50 Updated Boundary Distance", 
            'TM-50 Ground LOS Hold', 
            'TM-10 Ground LOS Hold'])

# **Note**
# 1. Ground LOS hold means the traffic manager will hold an aircraft on the ground if it is going to spawn in LOS.
#    Was seeking to reduce auto-LOS events
# 2. TM-<N> means the traffic manager was active with <N> capacity set. 25 capacity for each corridor seemed to be
#.   the best.

# %%
RM = 100

x_end = 20000 #len(nmac_no_tm)

print(f"Func-3a: {float(nmac_no_tm[:x_end].rolling(RM).mean().min())}")
print(f"TM-4: {float(nmac_tm_4[:x_end].rolling(RM).mean().min())}")
print(f"TM-25: {float(nmac_tm_25[:x_end].rolling(RM).mean().min())}")
print(f"TM-100: {float(nmac_tm_100[:x_end].rolling(RM).mean().min())}")
print(f"TM-50: {float(nmac_tm_50[:x_end].rolling(RM).mean().min())}")
print(f"TM-3: {float(nmac_tm_3[:x_end].rolling(RM).mean().min())}")
print(f"TM-50-Updated Boundary Distance: {float(nmac_tm_50_fix[:x_end].rolling(RM).mean().min())}")
print(f"TM-50-Ground LOS Hold: {float(nmac_tm_50_update[:x_end].rolling(RM).mean().min())}")
print(f"TM-10-Ground LOS Hold: {float(nmac_tm_10_update[:x_end].rolling(RM).mean().min())}")
# Out:
# Func-3a: 578.76
# TM-4: 608.16
# TM-25: 478.56
# TM-100: 514.84
# TM-50: 496.0
# TM-3: 609.48
# TM-50-fix: 527.28
# TM-50-update: 552.88
# TM-10-update: 19630.44
